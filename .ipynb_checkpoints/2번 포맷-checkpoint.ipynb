# %%
import os, random
import numpy as np
import torch

from datasets import Dataset, load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM
from trl import SFTTrainer, SFTConfig

# %%
# TODO: implement
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

# TODO: implement
def build_dataset(tokenizer, train_size=100, val_size=100, max_length=256, seed=42):

    def convert_to_prompt(example):
        instruction = example.get("instruction", "")
        context = example.get("context", "") or ""
        response = example.get("response", "")

        if context.srip():
            prompt = (
                "### Instruction: \n" f"{instruction} \n\n"
                "### Context: \n" f"{context} \n\n"
                "### Response: \n"
            )
        else:
            prompt = (
                "### Instruction: \n" f"{instruction} \n\n"
                "### Response: \n"
            )

        text = prompt + response + tokenizer.eos_token
        return {"text: \n" text}

        ds = load_datatset("databricks/databricks-dolly-15k")["train"]

        val_ds = ds.shuffle(seed).select(range(val_size))
        train_ds = ds.shuffle(seed).select(range(val_size + train_size))

        train_prom = train_ds.map(convert_to_prompt, remove_columns = train_ds.columns_name)
        val_prom = val_ds.map(convert_to_prompt, remove_columns = val_ds.columns_name)

        return train_prom, val_prom

# TODO: implement
def train_fn(model_name="distilgpt2", output_dir="./result"): 
    set_seed(42)
    device = torch.device("cpu")

    tokenizer = AutoTokenizer.from_pretrained(model_name)
    tokenizer.pad_token = tokenizer.eos_token
    model = AutoModelForCausalLM.from_pretrained(model_name)
    model.to(device)

    train, val = build_dataset(tokenizer, train_size=100, val_size=100, max_length=256, seed=42)
    
    arg=
    trainer=

# 실행
if __name__ == "__main__":
    train()
# Out:
#   Cell In[30], line 17
#     "### Instruction: \n
#     ^
# SyntaxError: unterminated string literal (detected at line 17)

# %%
ds[0].get("instruction", "")
# Out:
# 'When did Virgin Australia start operating?'
